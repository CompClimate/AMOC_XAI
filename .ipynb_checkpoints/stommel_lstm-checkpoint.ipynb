# %%
import keras
import numpy as np
from keras.models import Sequential, Model
from keras.layers import Dense, Reshape, Flatten, Input, Dropout
from keras.optimizers import Adam, SGD, RMSprop
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import os

# %%
# global constants
Sv=1.e9 # m^3/sec

# %%
# salinity only, linear forcing 
input_data = np.load('data/input_sal_temp_sine.npy')
output_data = np.load('data/output_sal_temp_sine.npy')

# %%
X_train = input_data[0:30000]
y_train = output_data[0:30000]
X_val = input_data[30000:50000]
y_val = output_data[30000:50000]
X_test = input_data[50000:100000]
y_test = output_data[50000:100000]

# %%
scaler = StandardScaler()
scaler.fit(X_train)
scaler.mean_,scaler.scale_

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)
input_scaled = scaler.transform(input_data)

Y_train = keras.utils.to_categorical(y_train)
Y_val = keras.utils.to_categorical(y_val)
Y_test = keras.utils.to_categorical(y_test)

# %%
# defining the MLP
model = Sequential()
model.add(Dense(12, input_dim=5, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model on the training set and validate on the validation set
model_eval = model.fit(X_train_scaled, Y_train, epochs=10, batch_size=32, validation_data=(X_val_scaled, Y_val))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 2s 1ms/step - loss: 0.3396 - accuracy: 0.9960 - val_loss: 0.3617 - val_accuracy: 0.9528
# Epoch 2/10
# 938/938 [==============================] - 1s 1ms/step - loss: 0.1443 - accuracy: 0.9997 - val_loss: 0.1670 - val_accuracy: 0.9934
# Epoch 3/10
# 938/938 [==============================] - 1s 1ms/step - loss: 0.0818 - accuracy: 0.9999 - val_loss: 0.1048 - val_accuracy: 0.9940
# Epoch 4/10
# 938/938 [==============================] - 1s 1ms/step - loss: 0.0498 - accuracy: 0.9999 - val_loss: 0.0628 - val_accuracy: 0.9973
# Epoch 5/10
# 938/938 [==============================] - 1s 1ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 0.9968
# Epoch 6/10
# 938/938 [==============================] - 1s 2ms/step - loss: 0.0207 - accuracy: 0.9998 - val_loss: 0.0285 - val_accuracy: 0.9980
# Epoch 7/10
# 938/938 [==============================] - 1s 2ms/step - loss: 0.0137 - accuracy: 0.9999 - val_loss: 0.0400 - val_accuracy: 0.9927
# Epoch 8/10
# 938/938 [==============================] - 1s 1ms/step - loss: 0.0092 - accuracy: 0.9999 - val_loss: 0.0163 - val_accuracy: 0.9975
# Epoch 9/10
# 938/938 [==============================] - 1s 1ms/step - loss: 0.0063 - accuracy: 0.9999 - val_loss: 0.0092 - val_accuracy: 0.9991
# Epoch 10/10
# 938/938 [==============================] - 1s 1ms/step - loss: 0.0043 - accuracy: 0.9999 - val_loss: 0.0098 - val_accuracy: 0.9979

# %%
loss, accuracy = model.evaluate(X_test_scaled, Y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# 1563/1563 [==============================] - 1s 728us/step - loss: 0.0336 - accuracy: 0.9943
# Test loss: 0.03358308970928192
# Test accuracy: 0.9943400025367737

# %%
plt.plot(model_eval.history['loss'], label='Training Loss');
plt.plot(model_eval.history['val_loss'], label='Validation Loss');
plt.title('Loss Plot');
plt.legend();

# %%
y_pred_all = model.predict(input_scaled)
# Out:
# 3125/3125 [==============================] - 2s 609us/step

# %%
y_labels_all = np.argmax(y_pred_all, axis=-1)

# %%
false_indices_sal_temp_sine = []
for i in range(len(y_labels_all)):
    if y_labels_all[i] != output_data[i]:
        false_indices_sal_temp_sine.append(i)

# %%
qplot = np.load('data/q_sal_temp_sine.npy')

# %%
plt.plot(input_data[:, 0], qplot/Sv);
plt.plot(input_data[:, 0], input_data[:, 0]*0,'k--');
plt.xlabel('t (time in kiloyears)');
plt.ylabel('$q$');
plt.title('Incorrect Predictions for AMOC');
plt.scatter([input_data[:, 0][i] for i in false_indices_sal_temp_sine], [qplot[i]/Sv for i in false_indices_sal_temp_sine], marker='x', c='red');

# %%
# training the ensemble 
for i in range(10):
    print(i)
    model = Sequential()
    model.add(Dense(12, input_dim=5, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(3, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
    history = model.fit(X_train_scaled, Y_train,
                    batch_size=8,
                    epochs=10,
                    verbose=0,
                    validation_data=(X_val_scaled, Y_val),
                    callbacks=[es])#,
    os.makedirs("models_nonrandom", exist_ok=True)
    model.save('models_nonrandom/stommel_model_ts_sine_'+str(i)+'.h5')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Epoch 6: early stopping
# 7
# 8
# 9

# %%
plt.plot(history.history['loss'], label='Training Loss');
plt.plot(history.history['val_loss'], label='Validation Loss');
plt.title('Loss Plot for Ensemble')
plt.legend();

# %%
accuracies = []

# %%
for i in range(10):
    print(i)
    model = Sequential()
    model.add(Dense(12, input_dim=5, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(3, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    model.load_weights('models_nonrandom/stommel_model_ts_sine_'+str(i)+'.h5')
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    loss, accuracy= model.evaluate(X_test_scaled, Y_test)
    accuracies.append(accuracy)
    print(f'Test loss: {loss}')
    print(f'Test accuracy: {accuracy}')
# Out:
# 0
# 1563/1563 [==============================] - 2s 939us/step - loss: 0.8756 - accuracy: 0.8970
# Test loss: 0.875575840473175
# Test accuracy: 0.8969600200653076
# 1
# 1563/1563 [==============================] - 1s 794us/step - loss: 0.5494 - accuracy: 0.9704
# Test loss: 0.5493618249893188
# Test accuracy: 0.9703999757766724
# 2
# 1563/1563 [==============================] - 1s 721us/step - loss: 0.0122 - accuracy: 0.9953
# Test loss: 0.0121502336114645
# Test accuracy: 0.9952800273895264
# 3
# 1563/1563 [==============================] - 1s 818us/step - loss: 0.0022 - accuracy: 0.9990
# Test loss: 0.002249310491606593
# Test accuracy: 0.998960018157959
# 4
# 1563/1563 [==============================] - 2s 1ms/step - loss: 0.0308 - accuracy: 0.9934
# Test loss: 0.03075627237558365
# Test accuracy: 0.9933800101280212
# 5
# 1563/1563 [==============================] - 1s 722us/step - loss: 0.1445 - accuracy: 0.9813
# Test loss: 0.14451631903648376
# Test accuracy: 0.9813200235366821
# 6
# 1563/1563 [==============================] - 1s 750us/step - loss: 0.1089 - accuracy: 0.9820
# Test loss: 0.10890237987041473
# Test accuracy: 0.9819599986076355
# 7
# 1563/1563 [==============================] - 1s 723us/step - loss: 0.4407 - accuracy: 0.9400
# Test loss: 0.44066300988197327
# Test accuracy: 0.9400399923324585
# 8
# 1563/1563 [==============================] - 1s 802us/step - loss: 0.1459 - accuracy: 0.9859
# Test loss: 0.14590470492839813
# Test accuracy: 0.9858599901199341
# 9
# 1563/1563 [==============================] - 1s 724us/step - loss: 0.4742 - accuracy: 0.9521
# Test loss: 0.4741850793361664
# Test accuracy: 0.9521399736404419

# %%
sum(accuracies)/10*100
# Out:
# 96.96300029754639

# %%
datapredicted_results_ensemble = np.nan * np.zeros((10, input_scaled.shape[0], 2))

for i in range(10):
    print(i)
    model = Sequential()
    model.add(Dense(12, input_dim=5, activation='relu'))
    model.add(Dense(6, activation='relu'))
    model.add(Dense(3, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    model.load_weights('models_nonrandom/stommel_model_ts_sine_'+str(i)+'.h5')
    datapredicted = model.predict(input_scaled)
    datapredicted_results_ensemble[i,...] = datapredicted
# Out:
# 0
# 3125/3125 [==============================] - 2s 641us/step
# 1
# 3125/3125 [==============================] - 2s 610us/step
# 2
# 3125/3125 [==============================] - 2s 584us/step
# 3
# 3125/3125 [==============================] - 2s 589us/step
# 4
# 3125/3125 [==============================] - 2s 605us/step
# 5
# 3125/3125 [==============================] - 2s 621us/step
# 6
# 3125/3125 [==============================] - 2s 708us/step
# 7
# 3125/3125 [==============================] - 2s 635us/step
# 8
# 3125/3125 [==============================] - 2s 629us/step
# 9
# 3125/3125 [==============================] - 2s 638us/step

# %%
y_pred_ensemble = np.mean(datapredicted_results_ensemble, 0).argmax(axis=-1)

# %%
false_indices_ts_sine_ensemble = []

# %%
for i in range(len(y_pred_ensemble)):
    if y_pred_ensemble[i] != output_data[i]:
        false_indices_ts_sine_ensemble.append(i)

# %%
false_indices_ts_sine_ensemble
# Out:
# [33388,
#  33389,
#  33390,
#  33391,
#  33392,
#  33393,
#  33394,
#  33395,
#  33396,
#  33397,
#  33398,
#  33399,
#  33400,
#  33401,
#  33402,
#  33403,
#  33404,
#  33405,
#  33406,
#  33407,
#  33408,
#  33409,
#  33410,
#  33411,
#  33412,
#  33413,
#  33414,
#  33415,
#  33416,
#  49902,
#  49903,
#  49904,
#  49905,
#  49906,
#  49907,
#  49908,
#  49909,
#  49910,
#  49911,
#  49912,
#  49913,
#  49914,
#  49915,
#  49916,
#  49917,
#  49918,
#  49919,
#  49920,
#  49921,
#  49922,
#  49923,
#  49924,
#  49925,
#  49926,
#  49927,
#  49928,
#  49929,
#  49930,
#  49931,
#  49932,
#  49933,
#  49934,
#  49935,
#  49936,
#  49937,
#  49938,
#  49939,
#  49940,
#  49941,
#  49942,
#  49943,
#  49944,
#  49945,
#  49946,
#  49947,
#  49948,
#  49949,
#  49950,
#  49951,
#  49952,
#  49953,
#  49954,
#  49955,
#  49956,
#  49957,
#  49958,
#  49959,
#  49960,
#  49961,
#  49962,
#  49963,
#  49964,
#  49965,
#  49966,
#  49967,
#  49968,
#  49969,
#  49970,
#  49971,
#  49972,
#  49973,
#  49974,
#  49975,
#  49976,
#  49977,
#  49978,
#  49979,
#  49980,
#  49981,
#  49982,
#  49983,
#  49984,
#  49985,
#  49986,
#  49987,
#  49988,
#  49989,
#  49990,
#  49991,
#  49992,
#  49993,
#  49994,
#  49995,
#  49996,
#  49997,
#  49998,
#  49999,
#  50000,
#  50001,
#  50002,
#  50003,
#  50004,
#  50005,
#  50006,
#  50007,
#  50008,
#  50009,
#  50010,
#  50011,
#  50012,
#  50013,
#  50014,
#  50015,
#  50016,
#  50017,
#  50018,
#  50019,
#  50020,
#  50021,
#  50022,
#  50023,
#  50024,
#  50025,
#  50026,
#  50027,
#  50028,
#  50029,
#  50030,
#  50031,
#  50032,
#  50033,
#  50034,
#  50035,
#  50036,
#  50037,
#  50038,
#  50039,
#  50040,
#  50041,
#  50042,
#  50043,
#  50044,
#  50045,
#  50046,
#  50047,
#  50048,
#  50049,
#  50050,
#  50051,
#  50052,
#  50053,
#  50054,
#  66722,
#  66723,
#  66724,
#  66725,
#  66726,
#  66727,
#  66728,
#  66729,
#  66730,
#  66731,
#  66732,
#  66733,
#  66734,
#  66735,
#  66736,
#  66737,
#  66738,
#  66739,
#  66740,
#  66741,
#  66742,
#  66743,
#  66744,
#  66745,
#  66746,
#  66747,
#  66748,
#  66749,
#  66750,
#  66751,
#  66752,
#  66753,
#  66754,
#  66755,
#  66756,
#  66757,
#  66758,
#  66759,
#  66760,
#  66761,
#  66762,
#  66763,
#  66764,
#  66765,
#  66766,
#  66767,
#  66768,
#  66769,
#  66770,
#  66771,
#  66772,
#  66773,
#  66774,
#  66775,
#  66776,
#  66777,
#  66778,
#  66779,
#  66780,
#  66781,
#  66782,
#  66783,
#  66784,
#  66785,
#  66786,
#  66787,
#  66788,
#  66789,
#  66790,
#  66791,
#  66792,
#  66793,
#  66794,
#  66795,
#  66796,
#  66797,
#  66798,
#  66799,
#  66800,
#  66801,
#  66802,
#  66803,
#  66804,
#  66805,
#  66806,
#  66807,
#  66808,
#  66809,
#  66810,
#  66811,
#  66812,
#  66813,
#  66814,
#  66815,
#  66816,
#  66817,
#  66818,
#  66819,
#  66820,
#  66821,
#  66822,
#  66823,
#  66824,
#  66825,
#  66826,
#  66827,
#  66828,
#  66829,
#  66830,
#  66831,
#  66832,
#  66833,
#  66834,
#  66835,
#  66836,
#  66837,
#  66838,
#  66839,
#  66840,
#  66841,
#  66842,
#  66843,
#  66844,
#  66845,
#  66846,
#  66847,
#  66848,
#  66849,
#  66850,
#  66851,
#  66852,
#  66853,
#  66854,
#  66855,
#  66856,
#  66857,
#  66858,
#  66859,
#  66860,
#  66861,
#  66862,
#  66863,
#  66864,
#  66865,
#  66866,
#  66867,
#  66868,
#  66869,
#  66870,
#  66871,
#  66872,
#  66873,
#  66874,
#  66875,
#  66876,
#  66877,
#  66878,
#  66879,
#  66880,
#  66881,
#  66882,
#  66883,
#  66884,
#  66885,
#  66886,
#  66887,
#  66888,
#  66889,
#  66890,
#  66891,
#  66892,
#  66893,
#  66894,
#  66895,
#  66896,
#  66897,
#  66898,
#  66899,
#  66900,
#  66901,
#  66902,
#  66903,
#  66904,
#  66905,
#  66906,
#  66907,
#  66908,
#  66909,
#  66910,
#  66911,
#  66912,
#  66913,
#  66914,
#  66915,
#  66916,
#  66917,
#  66918,
#  66919,
#  66920,
#  66921,
#  66922,
#  66923,
#  66924,
#  66925,
#  66926,
#  66927,
#  66928,
#  66929,
#  66930,
#  66931,
#  66932,
#  66933,
#  66934,
#  66935,
#  66936,
#  66937,
#  82915,
#  82916,
#  82917,
#  82918,
#  82919,
#  82920,
#  82921,
#  82922,
#  82923,
#  82924,
#  82925,
#  82926,
#  82927,
#  82928,
#  82929,
#  82930,
#  82931,
#  82932,
#  82933,
#  82934,
#  82935,
#  82936,
#  82937,
#  82938,
#  82939,
#  82940,
#  82941,
#  82942,
#  82943,
#  82944,
#  82945,
#  82946,
#  82947,
#  82948,
#  82949,
#  82950,
#  82951,
#  82952,
#  82953,
#  82954,
#  82955,
#  82956,
#  82957,
#  82958,
#  82959,
#  82960,
#  82961,
#  82962,
#  82963,
#  82964,
#  82965,
#  82966,
#  82967,
#  82968,
#  82969,
#  82970,
#  82971,
#  82972,
#  82973,
#  82974,
#  82975,
#  82976,
#  82977,
#  82978,
#  82979,
#  82980,
#  82981,
#  82982,
#  82983,
#  82984,
#  82985,
#  82986,
#  82987,
#  82988,
#  82989,
#  82990,
#  82991,
#  82992,
#  82993,
#  82994,
#  82995,
#  82996,
#  82997,
#  82998,
#  82999,
#  83000,
#  83001,
#  83002,
#  83003,
#  83004,
#  83005,
#  83006,
#  83007,
#  83008,
#  83009,
#  83010,
#  83011,
#  83012,
#  83013,
#  83014,
#  83015,
#  83016,
#  83017,
#  83018,
#  83019,
#  83020,
#  83021,
#  83022,
#  83023,
#  83024,
#  83025,
#  83026,
#  83027,
#  83028,
#  83029,
#  83030,
#  83031,
#  83032,
#  83033,
#  83034,
#  83035,
#  83036,
#  83037,
#  83038,
#  83039,
#  83040,
#  83041,
#  83042,
#  83043,
#  83044,
#  83045,
#  83046,
#  83047,
#  83048,
#  83049,
#  83050,
#  83051,
#  83052,
#  83053,
#  83054,
#  83055,
#  83056,
#  83057,
#  83058,
#  83059,
#  83060,
#  83061,
#  83062,
#  83063,
#  83064,
#  83065,
#  83066,
#  83067,
#  83068,
#  83069,
#  83070,
#  83071,
#  83072,
#  83073,
#  83074,
#  83075,
#  83076,
#  83077,
#  83078,
#  83079,
#  83080,
#  83081,
#  83082,
#  83083,
#  83084,
#  83085,
#  83086,
#  83087,
#  83088,
#  83089,
#  83090,
#  83091,
#  83092,
#  83093,
#  83094,
#  83095,
#  83096,
#  83097,
#  83098,
#  83099,
#  83100,
#  83101,
#  83102,
#  83103,
#  83104,
#  83105,
#  83106,
#  83107,
#  83108,
#  83109,
#  83110,
#  83111,
#  83112,
#  83113,
#  83114,
#  83115,
#  83116,
#  83117,
#  83118,
#  83119,
#  83120,
#  83121,
#  83122,
#  83123,
#  83124,
#  83125,
#  83126,
#  83127,
#  83128,
#  83129,
#  83130,
#  83131,
#  83132,
#  83133,
#  83134,
#  83135,
#  83136,
#  83137,
#  83138,
#  83139,
#  83140,
#  83141,
#  83142,
#  83143,
#  83144,
#  83145,
#  83146,
#  83147,
#  83148,
#  83149,
#  83150,
#  83151,
#  83152,
#  83153,
#  83154,
#  83155,
#  83156,
#  83157,
#  83158,
#  83159,
#  83160,
#  83161,
#  83162,
#  83163,
#  83164,
#  83165,
#  83166,
#  83167,
#  83168,
#  83169,
#  83170,
#  83171,
#  83172,
#  83173,
#  83174,
#  83175,
#  83176,
#  83177,
#  83178,
#  83179,
#  83180,
#  83181,
#  83182,
#  83183,
#  83184,
#  83185,
#  83186,
#  83187,
#  83188,
#  83189,
#  83190,
#  83191,
#  83192,
#  83193,
#  83194,
#  83195,
#  83196,
#  83197,
#  83198,
#  83199,
#  83200,
#  83201,
#  83202,
#  83203,
#  83204,
#  83205,
#  83206,
#  83207,
#  83208,
#  83209,
#  83210,
#  83211,
#  83212,
#  83213,
#  83214,
#  83215,
#  83216,
#  83217,
#  83218,
#  83219,
#  83220,
#  83221,
#  83222,
#  83223,
#  83224,
#  83225,
#  83226,
#  83227,
#  83228,
#  83229,
#  83230,
#  83231,
#  83232,
#  83233,
#  83234,
#  83235,
#  83236,
#  83237,
#  83238,
#  83239,
#  83240,
#  83241,
#  83242,
#  83243,
#  83244,
#  83245,
#  83246,
#  83247,
#  83248,
#  83249,
#  83250,
#  83251,
#  83252,
#  83253,
#  83254,
#  83255,
#  83256,
#  83257,
#  83258,
#  83259,
#  83260,
#  83261,
#  83262,
#  83263,
#  83264,
#  83265,
#  83266,
#  83267,
#  83268,
#  83269,
#  83270,
#  83271,
#  83272,
#  83273,
#  83274,
#  83275,
#  83276,
#  83277,
#  83278,
#  83279,
#  83280,
#  83281,
#  83282,
#  83283,
#  83284,
#  83285,
#  83286,
#  83287,
#  83288,
#  83289,
#  83290,
#  83291,
#  83292,
#  83293,
#  83294,
#  83295,
#  83296,
#  83297,
#  83298,
#  83299,
#  83300,
#  83301,
#  83302,
#  83303,
#  83304,
#  83305,
#  83306,
#  83307,
#  83308,
#  83309,
#  83310,
#  83311,
#  83312,
#  83313,
#  83314,
#  83315,
#  83316,
#  83317,
#  83318,
#  83319,
#  83320,
#  83321,
#  83322,
#  83323,
#  83324,
#  83325,
#  83326,
#  83327,
#  83328,
#  83329,
#  83330,
#  83331,
#  83332,
#  83333,
#  83334,
#  83335,
#  83336,
#  83337,
#  83338,
#  83339,
#  83340,
#  83341,
#  83342,
#  83343,
#  83344,
#  83345,
#  83346,
#  83347,
#  83348,
#  83349,
#  83350,
#  83351,
#  83352,
#  83353,
#  83354,
#  83355,
#  83356,
#  83357,
#  83358,
#  83359,
#  83360,
#  83361,
#  83362,
#  83363,
#  83364,
#  83365,
#  83366,
#  83367,
#  83368,
#  83369,
#  83370,
#  83371,
#  83372,
#  83373,
#  83374,
#  83375,
#  83376,
#  83377,
#  83378,
#  83379,
#  83380,
#  83381,
#  83382,
#  83383,
#  83384,
#  83385,
#  83386,
#  83387,
#  83388]

# %%
plt.plot(input_data[:, 0], qplot/Sv);
plt.plot(input_data[:, 0], input_data[:, 0]*0,'k--');
plt.xlabel('t (time in kiloyears)');
plt.ylabel('$q$');
plt.title('Incorrect Predictions for AMOC (Sine)');
plt.scatter([input_data[:, 0][i] for i in false_indices_ts_sine_ensemble], [qplot[i]/Sv for i in false_indices_ts_sine_ensemble], marker='x', c='red');
plt.savefig('predictions', dpi=200)
